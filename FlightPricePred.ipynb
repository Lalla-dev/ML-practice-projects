# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# !pip install openpyxl

# %%
df_train = pd.read_excel('/content/Data_Train.xlsx', engine = 'openpyxl')

# %%
df_test = pd.read_excel('/content/Test_set.xlsx',engine='openpyxl')

# %%
df_train.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df_test.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
pip install sheryanalysis==0.1.0

# %%
import sheryanalysis as sh
sh.analyze(df_train)
# Out:
# 🔍 Basic Analysis Report
# INFO:sheryanalysis:
# 🔍 Basic Analysis Report
# ------------------------------------------------------------
# INFO:sheryanalysis:------------------------------------------------------------
# 📏 Shape: (10683, 11)
# INFO:sheryanalysis:📏 Shape: (10683, 11)
# 🧱 Columns: ['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route', 'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops', 'Additional_Info', 'Price']
# INFO:sheryanalysis:🧱 Columns: ['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route', 'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops', 'Additional_Info', 'Price']
# 🧼 Columns with nulls: ['Route', 'Total_Stops']
# INFO:sheryanalysis:
# 🧼 Columns with nulls: ['Route', 'Total_Stops']
# 🔠 Categorical Columns: ['Airline', 'Source', 'Destination', 'Route', 'Duration', 'Total_Stops', 'Additional_Info']
# INFO:sheryanalysis:
# ...

# %%
df_final = pd.concat([df_train, df_test], ignore_index=True)

# %%
df_final
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore   New Delhi
# 1              Air India       1/05/2019   Kolkata    Banglore
# 2            Jet Airways       9/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore   New Delhi
# ...                  ...             ...       ...         ...
# 13349          Air India       6/06/2019   Kolkata    Banglore
# 13350             IndiGo      27/03/2019   Kolkata    Banglore
# 13351        Jet Airways       6/03/2019     Delhi      Cochin
# 13352          Air India       6/03/2019     Delhi      Cochin
# 13353  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# ...

# %%
df_final.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
df_final.tail()
# Out:
#                  Airline Date_of_Journey   Source Destination  \
# 13349          Air India       6/06/2019  Kolkata    Banglore
# 13350             IndiGo      27/03/2019  Kolkata    Banglore
# 13351        Jet Airways       6/03/2019    Delhi      Cochin
# 13352          Air India       6/03/2019    Delhi      Cochin
# 13353  Multiple carriers      15/06/2019    Delhi      Cochin
#
#                  Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 13349  CCU → DEL → BLR    20:30  20:25 07 Jun  23h 55m      1 stop
# 13350        CCU → BLR    14:20         16:55   2h 35m    non-stop
# 13351  DEL → BOM → COK    21:50  04:25 07 Mar   6h 35m      1 stop
# 13352  DEL → BOM → COK    04:00         19:15  15h 15m      1 stop
# 13353  DEL → BOM → COK    04:55         19:15  14h 20m      1 stop
#
#       Additional_Info  Price
# 13349         No info    NaN
# 13350         No info    NaN
# 13351         No info    NaN
# 13352         No info    NaN
# 13353         No info    NaN

# %%
df_test.tail()
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2666          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2667             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2668        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2669          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info
# 2666    20:30  20:25 07 Jun  23h 55m      1 stop         No info
# 2667    14:20         16:55   2h 35m    non-stop         No info
# 2668    21:50  04:25 07 Mar   6h 35m      1 stop         No info
# 2669    04:00         19:15  15h 15m      1 stop         No info
# 2670    04:55         19:15  14h 20m      1 stop         No info

# %%
df_train.tail()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10678              CCU → BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.1+ MB

# %%
##Feature Engineering

# %%
df_final['Date'] = df_final['Date_of_Journey'].str.split('/').str[0]
df_final['Month'] = df_final['Date_of_Journey'].str.split('/').str[1]
df_final['Year'] = df_final['Date_of_Journey'].str.split('/').str[2]

# %%
df_final.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0   01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# ...

# %%
df_final['Date']=df_final['Date'].astype(int)
df_final['Month']=df_final['Month'].astype(int)
df_final['Year']=df_final['Year'].astype(int)

# %%
df_final
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore   New Delhi
# 1              Air India       1/05/2019   Kolkata    Banglore
# 2            Jet Airways       9/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore   New Delhi
# ...                  ...             ...       ...         ...
# 13349          Air India       6/06/2019   Kolkata    Banglore
# 13350             IndiGo      27/03/2019   Kolkata    Banglore
# 13351        Jet Airways       6/03/2019     Delhi      Cochin
# 13352          Air India       6/03/2019     Delhi      Cochin
# 13353  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  int64
#  12  Month            13354 non-null  int64
#  13  Year             13354 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 1.4+ MB

# %%
df_final = df_final.drop('Date_of_Journey', axis=1)

# %%
df_final.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897.0    24      3
# 1         13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2  04:25 10 Jun      19h     2 stops         No info  13882.0     9      6
# 3         23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4         21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
print(type(df_final))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_final = pd.concat([df_train, df_test], ignore_index = True)

# %%
df_final['Date'] = df_final['Date_of_Journey'].str.split('/').str[0]
df_final['Month'] = df_final['Date_of_Journey'].str.split('/').str[1]
df_final['Year'] = df_final['Date_of_Journey'].str.split('/').str[2]

# %%
df_final = df_final.drop('Date_of_Journey', axis=1)

# %%
df_final.head(1)
# Out:
#   Airline    Source Destination      Route Dep_Time  Arrival_Time Duration  \
# 0  IndiGo  Banglore   New Delhi  BLR → DEL    22:20  01:10 22 Mar   2h 50m
#
#   Total_Stops Additional_Info   Price Date Month  Year
# 0    non-stop         No info  3897.0   24    03  2019

# %%
df_final['Arrival_Time']=df_final['Arrival_Time'].apply(lambda x : x.split(' ')[0])

# %%
 df_final.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# Date                  0
# Month                 0
# Year                  0
# dtype: int64

# %%
df_final['Arrival_hour'] = df_final['Arrival_Time'].apply(lambda x : x.split(':')[0])

# %%
df_final['Arrival_min'] = df_final['Arrival_Time'].apply(lambda x : x.split(':')[1])

# %%
df_final['Arrival_min'] = df_final['Arrival_Time'].apply(lambda x : x.split(' ')[0].split(':')[1])

# %%
df_final.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price Date Month  Year  \
# 0        01:10   2h 50m    non-stop         No info   3897.0   24    03  2019
# 1        13:15   7h 25m     2 stops         No info   7662.0    1    05  2019
# 2        04:25      19h     2 stops         No info  13882.0    9    06  2019
# 3        23:30   5h 25m      1 stop         No info   6218.0   12    05  2019
# 4        21:35   4h 45m      1 stop         No info  13302.0   01    03  2019
#
#   Arrival_hour Arrival_min
# 0           01          10
# ...

# %%
df_final['Arrival_hour'] = df_final['Arrival_hour'].astype(int)
df_final['Arrival_min'] = df_final['Arrival_min'].astype(int)

# %%
df_final = df_final.drop('Arrival_Time', axis=1)

# %%
df_final['Dep_hour'] = df_final['Dep_Time'].apply(lambda x : x.split(':')[0])
df_final['Dep_min'] = df_final['Dep_Time'].apply(lambda x : x.split(':')[1])
df_final = df_final.drop('Dep_Time', axis = 1)

# %%
df_final.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info    Price Date Month  Year  Arrival_hour  \
# 0    non-stop         No info   3897.0   24    03  2019             1
# 1     2 stops         No info   7662.0    1    05  2019            13
# 2     2 stops         No info  13882.0    9    06  2019             4
# 3      1 stop         No info   6218.0   12    05  2019            23
# 4      1 stop         No info  13302.0   01    03  2019            21
#
#    Arrival_min Dep_hour Dep_min
# 0           10       22      20
# 1           15       05      50
# ...

# %%
df_final['Dep_hour'] = df_final['Dep_hour'].astype(int)
df_final['Dep_min'] = df_final['Dep_min'].astype(int)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  object
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   Date             13354 non-null  object
#  9   Month            13354 non-null  object
#  10  Year             13354 non-null  object
#  11  Arrival_hour     13354 non-null  int64
#  12  Arrival_min      13354 non-null  int64
#  13  Dep_hour         13354 non-null  int64
#  14  Dep_min          13354 non-null  int64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 1.5+ MB

# %%
df_final.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Route', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price', 'Date', 'Month', 'Year', 'Arrival_hour',
#        'Arrival_min', 'Dep_hour', 'Dep_min'],
#       dtype='object')

# %%
df_final.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info    Price Date Month  Year  Arrival_hour  \
# 0    non-stop         No info   3897.0   24    03  2019             1
# 1     2 stops         No info   7662.0    1    05  2019            13
# 2     2 stops         No info  13882.0    9    06  2019             4
# 3      1 stop         No info   6218.0   12    05  2019            23
# 4      1 stop         No info  13302.0   01    03  2019            21
#
#    Arrival_min  Dep_hour  Dep_min
# 0           10        22       20
# 1           15         5       50
# ...

# %%
df_final['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
df_final['Total_Stops'].isnull().sum()
# Out:
# np.int64(1)

# %%
df_final['Total_Stops'] = df_final['Total_Stops'].map({'non-stop': 0, '2 stops':2, '1 stop':1, '3 stops':3, 'nan':1, '4 stops':4})

# %%
df_final.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#    Total_Stops Additional_Info    Price Date Month  Year  Arrival_hour  \
# 0          0.0         No info   3897.0   24    03  2019             1
# 1          2.0         No info   7662.0    1    05  2019            13
# 2          2.0         No info  13882.0    9    06  2019             4
# 3          1.0         No info   6218.0   12    05  2019            23
# 4          1.0         No info  13302.0   01    03  2019            21
#
#    Arrival_min  Dep_hour  Dep_min
# 0           10        22       20
# 1           15         5       50
# ...

# %%
df_final.drop('Route',axis=1,inplace = True)
df_final.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price Date Month  Year  Arrival_hour  Arrival_min  Dep_hour  Dep_min
# 0   3897.0   24    03  2019             1           10        22       20
# 1   7662.0    1    05  2019            13           15         5       50
# 2  13882.0    9    06  2019             4           25         9       25
# 3   6218.0   12    05  2019            23           30        18        5
# 4  13302.0   01    03  2019            21           35        16       50

# %%
df_final['Date'] = df_final['Date'].astype(int)
df_final['Month'] = df_final['Month'].astype(int)
df_final['Year'] = df_final['Year'].astype(int)
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Duration         13354 non-null  object
#  4   Total_Stops      13353 non-null  float64
#  5   Additional_Info  13354 non-null  object
#  6   Price            10683 non-null  float64
#  7   Date             13354 non-null  int64
#  8   Month            13354 non-null  int64
#  9   Year             13354 non-null  int64
#  10  Arrival_hour     13354 non-null  int64
#  11  Arrival_min      13354 non-null  int64
#  12  Dep_hour         13354 non-null  int64
#  13  Dep_min          13354 non-null  int64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 1.4+ MB

# %%
df_final['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
df_final['Duration'].unique()
# Out:
# array(['2h 50m', '7h 25m', '19h', '5h 25m', '4h 45m', '2h 25m', '15h 30m',
#        '21h 5m', '25h 30m', '7h 50m', '13h 15m', '2h 35m', '2h 15m',
#        '12h 10m', '26h 35m', '4h 30m', '22h 35m', '23h', '20h 35m',
#        '5h 10m', '15h 20m', '2h 55m', '13h 20m', '15h 10m', '5h 45m',
#        '5h 55m', '13h 25m', '22h', '5h 30m', '10h 25m', '5h 15m',
#        '2h 30m', '6h 15m', '11h 55m', '11h 5m', '8h 30m', '22h 5m',
#        '2h 45m', '12h', '16h 5m', '19h 55m', '3h 15m', '25h 20m', '3h',
#        '16h 15m', '15h 5m', '6h 30m', '25h 5m', '12h 25m', '27h 20m',
#        '10h 15m', '10h 30m', '1h 30m', '1h 25m', '26h 30m', '7h 20m',
#        '13h 30m', '5h', '19h 5m', '14h 50m', '2h 40m', '22h 10m',
#        '9h 35m', '10h', '21h 20m', '18h 45m', '12h 20m', '18h', '9h 15m',
#        '17h 30m', '16h 35m', '12h 15m', '7h 30m', '24h', '8h 55m',
#        '7h 10m', '14h 30m', '30h 20m', '15h', '12h 45m', '10h 10m',
#        '15h 25m', '14h 5m', '20h 15m', '23h 10m', '18h 10m', '16h',
# ...

# %%
df_final['Dur_hour'] = df_final['Duration'].str.split(' ').str[0].str.split('h').str[0]

df_final['Dur_min'] = df_final['Duration'].str.split(' ').str[1].str.split('m').str[0]


df_final.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_hour  Dep_min  \
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
# 3   6218.0    12      5  2019            23           30        18        5
# 4  13302.0     1      3  2019            21           35        16       50
#
#   Dur_hour Dur_min
# 0        2      50
# ...

# %%
df_final
# Out:
#                  Airline    Source Destination Duration  Total_Stops  \
# 0                 IndiGo  Banglore   New Delhi   2h 50m          0.0
# 1              Air India   Kolkata    Banglore   7h 25m          2.0
# 2            Jet Airways     Delhi      Cochin      19h          2.0
# 3                 IndiGo   Kolkata    Banglore   5h 25m          1.0
# 4                 IndiGo  Banglore   New Delhi   4h 45m          1.0
# ...                  ...       ...         ...      ...          ...
# 13349          Air India   Kolkata    Banglore  23h 55m          1.0
# 13350             IndiGo   Kolkata    Banglore   2h 35m          0.0
# 13351        Jet Airways     Delhi      Cochin   6h 35m          1.0
# 13352          Air India     Delhi      Cochin  15h 15m          1.0
# 13353  Multiple carriers     Delhi      Cochin  14h 20m          1.0
#
#       Additional_Info    Price  Date  Month  Year  Arrival_hour  Arrival_min  \
# ...

# %%
df_final['Dur_hour'].unique()
# Out:
# array(['2', '7', '19', '5', '4', '15', '21', '25', '13', '12', '26', '22',
#        '23', '20', '10', '6', '11', '8', '16', '3', '27', '1', '14', '9',
#        '18', '17', '24', '30', '28', '29', '37', '34', '38', '35', '36',
#        '47', '33', '32', '31', '42', '39', '5m', '41', '40'], dtype=object)

# %%
df_final.drop(6474,axis = 0, inplace = True)
df_final.drop(2660,axis = 0, inplace = True)

# %%
df_final[df_final['Dur_hour'] == '5m']
# Out:
#          Airline  Source Destination Duration  Total_Stops Additional_Info  \
# 13343  Air India  Mumbai   Hyderabad       5m          2.0         No info
#
#        Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_hour  Dep_min  \
# 13343    NaN    12      3  2019            16           55        16       50
#
#       Dur_hour Dur_min
# 13343       5m     NaN

# %%
df_final.drop(13343,axis = 0, inplace = True)

# %%
df_final[df_final['Dur_hour'] == '5m']
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Duration, Total_Stops, Additional_Info, Price, Date, Month, Year, Arrival_hour, Arrival_min, Dep_hour, Dep_min, Dur_hour, Dur_min]
# Index: []

# %%
import numpy as np
original_price_data = pd.concat([df_train['Price'], pd.Series([np.nan] * len(df_test), dtype=float)], ignore_index=True)
df_final['Price'] = original_price_data.loc[df_final.index]
df_final['Price'] = df_final['Price'].replace(np.nan, 0)
df_final['Price'].unique()
# Out:
# array([ 3897.,  7662., 13882., ..., 12352., 12648.,     0.])

# %%
df_final['Dur_min'].unique()
# Out:
# array(['50', '25', nan, '45', '30', '5', '15', '35', '10', '20', '55',
#        '40'], dtype=object)

# %%
df_final['Dur_hour'].unique()
# Out:
# array(['2', '7', '19', '5', '4', '15', '21', '25', '13', '12', '26', '22',
#        '23', '20', '10', '6', '11', '8', '16', '3', '27', '1', '14', '9',
#        '18', '17', '24', '30', '28', '29', '37', '34', '38', '35', '36',
#        '47', '33', '32', '31', '42', '39', '41', '40'], dtype=object)

# %%
df_final['Dur_min'] = df_final['Dur_min'].map({'NaN':0,'nan':0})

# %%
df_final['Price'] = df_final['Price'].replace(np.nan, 0)

# %%
df_final['Price'].astype(int)
# Out:
# 0         3897
# 1         7662
# 2        13882
# 3         6218
# 4        13302
#          ...
# 13349        0
# 13350        0
# 13351        0
# 13352        0
# 13353        0
# Name: Price, Length: 13351, dtype: int64

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13351 entries, 0 to 13353
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13351 non-null  object
#  1   Source           13351 non-null  object
#  2   Destination      13351 non-null  object
#  3   Duration         13351 non-null  object
#  4   Total_Stops      13350 non-null  float64
#  5   Additional_Info  13351 non-null  object
#  6   Price            13351 non-null  float64
#  7   Date             13351 non-null  int64
#  8   Month            13351 non-null  int64
#  9   Year             13351 non-null  int64
#  10  Arrival_hour     13351 non-null  int64
#  11  Arrival_min      13351 non-null  int64
#  12  Dep_hour         13351 non-null  int64
#  13  Dep_min          13351 non-null  int64
#  14  Dur_hour         13351 non-null  object
#  15  Dur_min          0 non-null      float64
# dtypes: float64(3), int64(7), object(6)
# ...

# %%
df_final.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_hour  Dep_min  \
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
# 3   6218.0    12      5  2019            23           30        18        5
# 4  13302.0     1      3  2019            21           35        16       50
#
#   Dur_hour  Dur_min
# 0        2      NaN
# ...

# %%
df_final['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
df_final['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
df_final['Destination'].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df_final= pd.get_dummies(df_final,columns = ['Airline'],drop_first = True)

# %%
Airline_col =['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
       'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
       'Vistara Premium economy', 'Jet Airways Business',
       'Multiple carriers Premium economy', 'Trujet']

# %%
airline_dummy_cols = [col for col in df_final.columns if col.startswith('Airline_')]
df_final[airline_dummy_cols] = df_final[airline_dummy_cols].astype(int)

# %%
df_final
# Out:
#          Source Destination Duration  Total_Stops Additional_Info    Price  \
# 0      Banglore   New Delhi   2h 50m          0.0         No info   3897.0
# 1       Kolkata    Banglore   7h 25m          2.0         No info   7662.0
# 2         Delhi      Cochin      19h          2.0         No info  13882.0
# 3       Kolkata    Banglore   5h 25m          1.0         No info   6218.0
# 4      Banglore   New Delhi   4h 45m          1.0         No info  13302.0
# ...         ...         ...      ...          ...             ...      ...
# 13349   Kolkata    Banglore  23h 55m          1.0         No info      0.0
# 13350   Kolkata    Banglore   2h 35m          0.0         No info      0.0
# 13351     Delhi      Cochin   6h 35m          1.0         No info      0.0
# 13352     Delhi      Cochin  15h 15m          1.0         No info      0.0
# 13353     Delhi      Cochin  14h 20m          1.0         No info      0.0
#
# ...

# %%
df_final = pd.get_dummies(df_final, columns = ['Source'], drop_first= True)

# %%
source_dummy_cols = [col for col in df_final.columns if col.startswith('Source')]
df_final[source_dummy_cols] = df_final[source_dummy_cols].astype(int)

# %%
df_final
# Out:
#       Destination Duration  Total_Stops Additional_Info    Price  Date  Month  \
# 0       New Delhi   2h 50m          0.0         No info   3897.0    24      3
# 1        Banglore   7h 25m          2.0         No info   7662.0     1      5
# 2          Cochin      19h          2.0         No info  13882.0     9      6
# 3        Banglore   5h 25m          1.0         No info   6218.0    12      5
# 4       New Delhi   4h 45m          1.0         No info  13302.0     1      3
# ...           ...      ...          ...             ...      ...   ...    ...
# 13349    Banglore  23h 55m          1.0         No info      0.0     6      6
# 13350    Banglore   2h 35m          0.0         No info      0.0    27      3
# 13351      Cochin   6h 35m          1.0         No info      0.0     6      3
# 13352      Cochin  15h 15m          1.0         No info      0.0     6      3
# 13353      Cochin  14h 20m          1.0         No info      0.0    15      6
#
# ...

# %%
df_final = pd.get_dummies(df_final, columns = ['Destination'], drop_first= True)

# %%
destination_dummy_cols = [col for col in df_final.columns if col.startswith('Destination')]
df_final[destination_dummy_cols] = df_final[destination_dummy_cols].astype(int)

# %%
df_final
# Out:
#       Duration  Total_Stops Additional_Info    Price  Date  Month  Year  \
# 0       2h 50m          0.0         No info   3897.0    24      3  2019
# 1       7h 25m          2.0         No info   7662.0     1      5  2019
# 2          19h          2.0         No info  13882.0     9      6  2019
# 3       5h 25m          1.0         No info   6218.0    12      5  2019
# 4       4h 45m          1.0         No info  13302.0     1      3  2019
# ...        ...          ...             ...      ...   ...    ...   ...
# 13349  23h 55m          1.0         No info      0.0     6      6  2019
# 13350   2h 35m          0.0         No info      0.0    27      3  2019
# 13351   6h 35m          1.0         No info      0.0     6      3  2019
# 13352  15h 15m          1.0         No info      0.0     6      3  2019
# 13353  14h 20m          1.0         No info      0.0    15      6  2019
#
#        Arrival_hour  Arrival_min  Dep_hour  ...  \
# 0                 1           10        22  ...
# ...

# %%
df_final.shape
# Out:
# (13351, 33)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13351 entries, 0 to 13353
# Data columns (total 33 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Duration                                   13351 non-null  object
#  1   Total_Stops                                13350 non-null  float64
#  2   Additional_Info                            13351 non-null  object
#  3   Price                                      13351 non-null  float64
#  4   Date                                       13351 non-null  int64
#  5   Month                                      13351 non-null  int64
#  6   Year                                       13351 non-null  int64
#  7   Arrival_hour                               13351 non-null  int64
#  8   Arrival_min                                13351 non-null  int64
#  9   Dep_hour                                   13351 non-null  int64
# ...

# %%
df_final['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
df_final = pd.get_dummies(df_final, columns=['Additional_Info'], drop_first=True)

# %%
df_final.drop('Additional_Info', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_9981/1515733749.py in <cell line: 0>()
# ----> 1 df_final.drop('Additional_Info', axis=1, inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df_final['Additional_Info'] = df_final['Additional_Info'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Additional_Info'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_9981/2577760618.py in <cell line: 0>()
# ...

# %%
df_final
# Out:
#       Duration  Total_Stops    Price  Date  Month  Year  Arrival_hour  \
# 0       2h 50m          0.0   3897.0    24      3  2019             1
# 1       7h 25m          2.0   7662.0     1      5  2019            13
# 2          19h          2.0  13882.0     9      6  2019             4
# 3       5h 25m          1.0   6218.0    12      5  2019            23
# 4       4h 45m          1.0  13302.0     1      3  2019            21
# ...        ...          ...      ...   ...    ...   ...           ...
# 13349  23h 55m          1.0      0.0     6      6  2019            20
# 13350   2h 35m          0.0      0.0    27      3  2019            16
# 13351   6h 35m          1.0      0.0     6      3  2019             4
# 13352  15h 15m          1.0      0.0     6      3  2019            19
# 13353  14h 20m          1.0      0.0    15      6  2019            19
#
#        Arrival_min  Dep_hour  Dep_min  ... Destination_New Delhi  \
# ...

# %%
bool_cols = df_final.select_dtypes(include='bool').columns

df_final[bool_cols] = df_final[bool_cols].astype(int)

# %%
df_final
# Out:
#       Duration  Total_Stops    Price  Date  Month  Year  Arrival_hour  \
# 0       2h 50m          0.0   3897.0    24      3  2019             1
# 1       7h 25m          2.0   7662.0     1      5  2019            13
# 2          19h          2.0  13882.0     9      6  2019             4
# 3       5h 25m          1.0   6218.0    12      5  2019            23
# 4       4h 45m          1.0  13302.0     1      3  2019            21
# ...        ...          ...      ...   ...    ...   ...           ...
# 13349  23h 55m          1.0      0.0     6      6  2019            20
# 13350   2h 35m          0.0      0.0    27      3  2019            16
# 13351   6h 35m          1.0      0.0     6      3  2019             4
# 13352  15h 15m          1.0      0.0     6      3  2019            19
# 13353  14h 20m          1.0      0.0    15      6  2019            19
#
#        Arrival_min  Dep_hour  Dep_min  ... Destination_New Delhi  \
# ...
